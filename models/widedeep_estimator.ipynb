# %%
import pandas as pd
import numpy as np
import tensorflow as tf
from sklearn.model_selection import train_test_split
import os

# %%
class WideDeep:
    def __init__(self, train_df, eval_df, params):
        self.train_df = train_df
        self.eval_df = eval_df
        self.params = params
        self.estimator = tf.estimator.Estimator(model_fn=self.model_fn, params=self.params,
                                                model_dir=self.params["check_point_path"])

    def input_fn(self,df, num_epochs, shuffle, batch_size, predict=False):
        if not predict:
            labels = tf.constant(df[params['label_column']].apply(int).values)
        else:
            labels = tf.constant(np.zeros(df.shape[0]))

        features = {}
        for c in df.columns:
            if c != params['label_column']:
                features[c] = tf.constant(df[c].values)

        data_set = tf.data.Dataset.from_tensor_slices((features, labels))
        if shuffle:
            data_set = data_set.shuffle(100)
        data_set = data_set.repeat(num_epochs)
        data_set = data_set.batch(batch_size)
        return data_set

    def model_fn(self, features, labels, mode, params):
        wide = tf.feature_column.input_layer(features, params['wide_features'])
        wide = tf.layers.dense(wide, units=params["n_classes"])

        deep = tf.feature_column.input_layer(features, params['deep_features'])
        for units in params['hidden_units']:
            deep = tf.layers.dense(deep, units=units, activation=tf.nn.relu)
        deep = tf.layers.dense(deep, units=params['n_classes'])

        logits = wide + deep

        if mode == tf.estimator.ModeKeys.PREDICT:
            prob = tf.nn.softmax(logits)
            predicted_indices = tf.argmax(prob, 1)
            predictions = {
                'class': tf.gather(params['classes'], predicted_indices),
                'prob': prob
            }
            export_outputs = {
                'prediction': tf.estimator.export.PredictOutput(prob)
            }
            return tf.estimator.EstimatorSpec(mode,
                                              predictions=predictions,
                                              export_outputs=export_outputs)

        loss = tf.losses.sparse_softmax_cross_entropy(logits=logits, labels=labels)
        tf.summary.scalar("loss", loss)

        if mode == tf.estimator.ModeKeys.TRAIN:
            optimizer = tf.train.AdamOptimizer(learning_rate=self.params['lr'])
            train_op = optimizer.minimize(loss=loss, global_step=tf.train.get_global_step())
            return tf.estimator.EstimatorSpec(mode=mode,
                                              loss=loss,
                                              train_op=train_op)

        if mode == tf.estimator.ModeKeys.EVAL:
            prob = tf.nn.softmax(logits)
            predicted_indices = tf.argmax(prob, 1)
            labels_one_hot = tf.one_hot(
                labels,
                depth=2,
            )
            eval_metric_ops = {
                'accuracy': tf.metrics.accuracy(labels, predicted_indices),
                'auroc': tf.metrics.auc(labels_one_hot, prob)
            }
            return tf.estimator.EstimatorSpec(mode,
                                              loss=loss,
                                              eval_metric_ops=eval_metric_ops)

    def train_input_fn(self):
        return self.input_fn(self.train_df, self.params['num_epochs_evals'],
                             self.params['shuffle'], self.params['batch_size'], False)

    def eval_input_fn(self):
        return self.input_fn(self.train_df, 1, self.params['shuffle'], self.params['batch_size'], False)

    def train_with_early_stopping(self, metric_key="accuracy"):
        eval_results = []
        no_growth = 0
        for n in range(self.params['num_epochs'] // self.params['num_epochs_evals']):
            self.estimator.train(input_fn=self.train_input_fn)
            results = self.estimator.evaluate(input_fn=self.eval_input_fn)

            print("EVAL", " ".join(['%s: %-10s\t' % (key, results[key]) for key in sorted(results)]))

            if len(eval_results) < 5:
                eval_results.append(results)
                no_growth = 0
            elif results[metric_key] > max(eval_results, key=lambda x: x[metric_key])[metric_key]:
                eval_results.pop(0)
                eval_results.append(results)
                no_growth = 0
            else:
                no_growth += 1

            if no_growth > 3:
                break
        return max(eval_results, key=lambda x: x[metric_key])

    def predict(self, bst_steps, test_df):
        ckp_path = self.params['check_point_path'] + "model.ckpt-%d" % bst_steps
        res = self.estimator.predict(lambda: self.input_fn(test_df, 1, False, params['batch_size'], True),
                                     checkpoint_path=ckp_path)
        return res

# %%
def dataprocess():
    train = pd.read_csv("../data/train.csv")
    test = pd.read_csv("../data/test.csv")

    df = pd.concat([train, test], axis=0)
    df.drop(["Name", "PassengerId", "Ticket"], axis=1, inplace=True)

    df.Cabin.fillna("", inplace=True)
    df.Embarked.fillna("", inplace=True)
    df.Fare.fillna(0, inplace=True)
    df.Age.fillna(0, inplace=True)
    return df

# %%
def get_wide_deep_columns(df):
    numeric_columns = ["Age", "Fare", "Parch", "SibSp"]
    category_columns = ["Cabin", "Embarked", "Sex", "Pclass"]
    features = {}
    for c in numeric_columns:
        features[c] = tf.feature_column.numeric_column(c)
    for c in category_columns:
        features[c] = tf.feature_column.categorical_column_with_vocabulary_list(c, df[c].unique())

    age_buckets = tf.feature_column.bucketized_column(features["Age"], [6, 18, 25, 30, 35, 40, 45, 50, 55, 60, 65])

    fare_span = (df.Fare.max() - df.Fare.min()) // 10 + 1
    fare_buckets = tf.feature_column.bucketized_column(features["Fare"], [i * fare_span for i in range(10)])

    # embedding
    cabin_emb = tf.feature_column.embedding_column(features["Cabin"], dimension=8)
    embarked_emb = tf.feature_column.embedding_column(features['Embarked'], dimension=8)
    age_emb = tf.feature_column.embedding_column(age_buckets, dimension=8)
    fare_emb = tf.feature_column.embedding_column(fare_buckets, dimension=8)

    # one-hot
    sex_one_hot = tf.feature_column.indicator_column(features['Sex'])
    pclass_one_hot = tf.feature_column.indicator_column(features['Pclass'])
    cabin_one_hot = tf.feature_column.indicator_column(features['Cabin'])
    embarked_one_hot = tf.feature_column.indicator_column(features['Embarked'])

    wide_columns = [features[c] for c in numeric_columns] + [sex_one_hot, pclass_one_hot, cabin_one_hot,
                                                             embarked_one_hot]
    deep_columns = [features[c] for c in numeric_columns] + [sex_one_hot, pclass_one_hot, cabin_emb, embarked_emb,
                                                             age_emb, fare_emb]

    return wide_columns, deep_columns

# %%
df = dataprocess()
wide_columns, deep_columns = get_wide_deep_columns(df)

train_df, valid_df = train_test_split(df[df.Survived.notna()], test_size=0.2)
# Out:
# /home/LAB/yanhao/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:5: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """

# %%
params = {
    "label_column": "Survived",
    "num_epochs": 30,
    "num_epochs_evals": 1,
    "hidden_units": [100, 20],
    "wide_features": wide_columns,
    "deep_features": deep_columns,
    "n_classes": 2,
    "lr": 0.1,
    "batch_size": 32,
    "shuffle": True,
    "classes": [0, 1],
    "check_point_path": "../model_output/checkpoint/"
}
if os.path.exists(params['check_point_path']):
    for root, dirs, files in os.walk(params['check_point_path'], topdown=False):
        for name in files:
            os.remove(os.path.join(root, name))
        for name in dirs:
            os.rmdir(os.path.join(root, name))

# %%
train_df, valid_df = train_test_split(df[df.Survived.notna()], test_size=0.2)

model = WideDeep(train_df, valid_df, params)
bst = model.train_with_early_stopping()

test_df = df[df.Survived.isna()]
# Out:
# INFO:tensorflow:Using default config.
# INFO:tensorflow:Using config: {'_model_dir': '../model_output/checkpoint/', '_tf_random_seed': None, '_save_summary_steps': 100, '_save_checkpoints_steps': None, '_save_checkpoints_secs': 600, '_session_config': allow_soft_placement: true
# graph_options {
#   rewrite_options {
#     meta_optimizer_iterations: ONE
#   }
# }
# , '_keep_checkpoint_max': 5, '_keep_checkpoint_every_n_hours': 10000, '_log_step_count_steps': 100, '_train_distribute': None, '_device_fn': None, '_protocol': None, '_eval_distribute': None, '_experimental_distribute': None, '_service': None, '_cluster_spec': <tensorflow.python.training.server_lib.ClusterSpec object at 0x7f1eec0cb438>, '_task_type': 'worker', '_task_id': 0, '_global_id_in_cluster': 0, '_master': '', '_evaluation_master': '', '_is_chief': True, '_num_ps_replicas': 0, '_num_worker_replicas': 1}
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 0 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 5.068536, step = 1
# INFO:tensorflow:Saving checkpoints for 23 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.44589335.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:43:21
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-23
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:43:22
# INFO:tensorflow:Saving dict for global step 23: accuracy = 0.7696629, auroc = 0.84270555, global_step = 23, loss = 0.9138803
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 23: ../model_output/checkpoint/model.ckpt-23
# EVAL accuracy: 0.7696629 	 auroc: 0.84270555	 global_step: 23        	 loss: 0.9138803
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-23
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 23 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.52225405, step = 24
# INFO:tensorflow:Saving checkpoints for 46 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.4310325.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:43:28
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-46
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:43:29
# INFO:tensorflow:Saving dict for global step 46: accuracy = 0.7485955, auroc = 0.82820106, global_step = 46, loss = 1.1475492
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 46: ../model_output/checkpoint/model.ckpt-46
# EVAL accuracy: 0.7485955 	 auroc: 0.82820106	 global_step: 46        	 loss: 1.1475492
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-46
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 46 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.9408045, step = 47
# INFO:tensorflow:Saving checkpoints for 69 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.8811243.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:43:35
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-69
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:43:36
# INFO:tensorflow:Saving dict for global step 69: accuracy = 0.79353935, auroc = 0.86589247, global_step = 69, loss = 0.67917424
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 69: ../model_output/checkpoint/model.ckpt-69
# EVAL accuracy: 0.79353935	 auroc: 0.86589247	 global_step: 69        	 loss: 0.67917424
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-69
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 69 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.6133919, step = 70
# INFO:tensorflow:Saving checkpoints for 92 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.03482316.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:43:42
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-92
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:43:43
# INFO:tensorflow:Saving dict for global step 92: accuracy = 0.8005618, auroc = 0.86596644, global_step = 92, loss = 0.58915716
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 92: ../model_output/checkpoint/model.ckpt-92
# EVAL accuracy: 0.8005618 	 auroc: 0.86596644	 global_step: 92        	 loss: 0.58915716
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-92
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 92 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.41307876, step = 93
# INFO:tensorflow:Saving checkpoints for 115 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.3169688.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:43:49
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-115
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:43:50
# INFO:tensorflow:Saving dict for global step 115: accuracy = 0.7514045, auroc = 0.81200486, global_step = 115, loss = 0.9609602
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 115: ../model_output/checkpoint/model.ckpt-115
# EVAL accuracy: 0.7514045 	 auroc: 0.81200486	 global_step: 115       	 loss: 0.9609602
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-115
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 115 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.86048365, step = 116
# INFO:tensorflow:Saving checkpoints for 138 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.8472581.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:43:56
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-138
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:43:56
# INFO:tensorflow:Saving dict for global step 138: accuracy = 0.81179774, auroc = 0.89102453, global_step = 138, loss = 0.5122901
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 138: ../model_output/checkpoint/model.ckpt-138
# EVAL accuracy: 0.81179774	 auroc: 0.89102453	 global_step: 138       	 loss: 0.5122901
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-138
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 138 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.41356194, step = 139
# INFO:tensorflow:Saving checkpoints for 161 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 2.0247715.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:02
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-161
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:03
# INFO:tensorflow:Saving dict for global step 161: accuracy = 0.73595506, auroc = 0.82318264, global_step = 161, loss = 1.0327531
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 161: ../model_output/checkpoint/model.ckpt-161
# EVAL accuracy: 0.73595506	 auroc: 0.82318264	 global_step: 161       	 loss: 1.0327531
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-161
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 161 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 1.2151065, step = 162
# INFO:tensorflow:Saving checkpoints for 184 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.7075294.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:09
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-184
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:10
# INFO:tensorflow:Saving dict for global step 184: accuracy = 0.67134833, auroc = 0.76766664, global_step = 184, loss = 0.8387256
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 184: ../model_output/checkpoint/model.ckpt-184
# EVAL accuracy: 0.67134833	 auroc: 0.76766664	 global_step: 184       	 loss: 0.8387256
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-184
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 184 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 1.127435, step = 185
# INFO:tensorflow:Saving checkpoints for 207 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.056005653.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:16
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-207
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:17
# INFO:tensorflow:Saving dict for global step 207: accuracy = 0.83707863, auroc = 0.89618766, global_step = 207, loss = 0.5013761
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 207: ../model_output/checkpoint/model.ckpt-207
# EVAL accuracy: 0.83707863	 auroc: 0.89618766	 global_step: 207       	 loss: 0.5013761
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-207
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 207 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.7797416, step = 208
# INFO:tensorflow:Saving checkpoints for 230 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.515537.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:23
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:24
# INFO:tensorflow:Saving dict for global step 230: accuracy = 0.7921348, auroc = 0.8710981, global_step = 230, loss = 0.47618273
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 230: ../model_output/checkpoint/model.ckpt-230
# EVAL accuracy: 0.7921348 	 auroc: 0.8710981 	 global_step: 230       	 loss: 0.47618273
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-230
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 230 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.4782277, step = 231
# INFO:tensorflow:Saving checkpoints for 253 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.49238312.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:30
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-253
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:31
# INFO:tensorflow:Saving dict for global step 253: accuracy = 0.83426964, auroc = 0.9024143, global_step = 253, loss = 0.48031068
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 253: ../model_output/checkpoint/model.ckpt-253
# EVAL accuracy: 0.83426964	 auroc: 0.9024143 	 global_step: 253       	 loss: 0.48031068
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-253
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 253 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.7251004, step = 254
# INFO:tensorflow:Saving checkpoints for 276 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 1.9553318.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:37
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-276
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:38
# INFO:tensorflow:Saving dict for global step 276: accuracy = 0.7949438, auroc = 0.8744457, global_step = 276, loss = 0.6227829
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 276: ../model_output/checkpoint/model.ckpt-276
# EVAL accuracy: 0.7949438 	 auroc: 0.8744457 	 global_step: 276       	 loss: 0.6227829
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-276
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 276 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.59721744, step = 277
# INFO:tensorflow:Saving checkpoints for 299 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.6390926.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:44
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-299
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:45
# INFO:tensorflow:Saving dict for global step 299: accuracy = 0.84129214, auroc = 0.90144473, global_step = 299, loss = 0.5612391
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 299: ../model_output/checkpoint/model.ckpt-299
# EVAL accuracy: 0.84129214	 auroc: 0.90144473	 global_step: 299       	 loss: 0.5612391
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-299
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 299 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.2566624, step = 300
# INFO:tensorflow:Saving checkpoints for 322 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.03805522.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:51
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-322
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:52
# INFO:tensorflow:Saving dict for global step 322: accuracy = 0.7991573, auroc = 0.8805736, global_step = 322, loss = 0.6526301
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 322: ../model_output/checkpoint/model.ckpt-322
# EVAL accuracy: 0.7991573 	 auroc: 0.8805736 	 global_step: 322       	 loss: 0.6526301
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-322
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 322 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.6814867, step = 323
# INFO:tensorflow:Saving checkpoints for 345 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.35879385.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:44:58
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-345
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:44:59
# INFO:tensorflow:Saving dict for global step 345: accuracy = 0.8244382, auroc = 0.89232934, global_step = 345, loss = 0.47917503
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 345: ../model_output/checkpoint/model.ckpt-345
# EVAL accuracy: 0.8244382 	 auroc: 0.89232934	 global_step: 345       	 loss: 0.47917503
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-345
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 345 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.20206122, step = 346
# INFO:tensorflow:Saving checkpoints for 368 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.7761692.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:45:05
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-368
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:45:05
# INFO:tensorflow:Saving dict for global step 368: accuracy = 0.7752809, auroc = 0.84743685, global_step = 368, loss = 0.88718206
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 368: ../model_output/checkpoint/model.ckpt-368
# EVAL accuracy: 0.7752809 	 auroc: 0.84743685	 global_step: 368       	 loss: 0.88718206
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Create CheckpointSaverHook.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-368
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Saving checkpoints for 368 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:loss = 0.9227903, step = 369
# INFO:tensorflow:Saving checkpoints for 391 into ../model_output/checkpoint/model.ckpt.
# INFO:tensorflow:Loss for final step: 0.16697446.
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Starting evaluation at 2018-11-02-09:45:12
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-391
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# INFO:tensorflow:Finished evaluation at 2018-11-02-09:45:12
# INFO:tensorflow:Saving dict for global step 391: accuracy = 0.8398876, auroc = 0.9025563, global_step = 391, loss = 0.4794019
# INFO:tensorflow:Saving 'checkpoint_path' summary for global step 391: ../model_output/checkpoint/model.ckpt-391
# EVAL accuracy: 0.8398876 	 auroc: 0.9025563 	 global_step: 391       	 loss: 0.4794019

# %%
res = model.predict(bst["global_step"], test_df)

# %%
for i in res:
    print(i)
# Out:
# INFO:tensorflow:Calling model_fn.
# INFO:tensorflow:Done calling model_fn.
# INFO:tensorflow:Graph was finalized.
# INFO:tensorflow:Restoring parameters from ../model_output/checkpoint/model.ckpt-299
# INFO:tensorflow:Running local_init_op.
# INFO:tensorflow:Done running local_init_op.
# {'class': 0, 'prob': array([0.9866203, 0.0133797], dtype=float32)}
# {'class': 0, 'prob': array([0.989985  , 0.01001506], dtype=float32)}
# {'class': 0, 'prob': array([9.9976701e-01, 2.3294809e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.99880683, 0.00119318], dtype=float32)}
# {'class': 0, 'prob': array([0.71064955, 0.2893505 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9947543 , 0.00524571], dtype=float32)}
# {'class': 1, 'prob': array([0.20390546, 0.79609454], dtype=float32)}
# {'class': 0, 'prob': array([0.9920771 , 0.00792296], dtype=float32)}
# {'class': 1, 'prob': array([0.29701737, 0.7029826 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9988342 , 0.00116581], dtype=float32)}
# {'class': 0, 'prob': array([0.990537  , 0.00946305], dtype=float32)}
# {'class': 0, 'prob': array([0.99875426, 0.00124569], dtype=float32)}
# {'class': 1, 'prob': array([0.05779359, 0.94220644], dtype=float32)}
# {'class': 0, 'prob': array([9.9996316e-01, 3.6863425e-05], dtype=float32)}
# {'class': 0, 'prob': array([9.9999845e-01, 1.5336911e-06], dtype=float32)}
# {'class': 1, 'prob': array([0.05086995, 0.94913006], dtype=float32)}
# {'class': 0, 'prob': array([0.9677952 , 0.03220474], dtype=float32)}
# {'class': 0, 'prob': array([0.9924953, 0.0075047], dtype=float32)}
# {'class': 0, 'prob': array([0.8236658 , 0.17633413], dtype=float32)}
# {'class': 0, 'prob': array([0.91931474, 0.0806853 ], dtype=float32)}
# {'class': 0, 'prob': array([9.9980670e-01, 1.9332062e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.9953708 , 0.00462915], dtype=float32)}
# {'class': 1, 'prob': array([0.00815423, 0.9918458 ], dtype=float32)}
# {'class': 0, 'prob': array([0.8359963 , 0.16400366], dtype=float32)}
# {'class': 1, 'prob': array([2.9664085e-09, 1.0000000e+00], dtype=float32)}
# {'class': 0, 'prob': array([9.9981242e-01, 1.8758178e-04], dtype=float32)}
# {'class': 1, 'prob': array([0.00227084, 0.9977291 ], dtype=float32)}
# {'class': 0, 'prob': array([0.99312747, 0.0068726 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9431678, 0.0568322], dtype=float32)}
# {'class': 0, 'prob': array([0.988734  , 0.01126607], dtype=float32)}
# {'class': 0, 'prob': array([0.99774384, 0.00225614], dtype=float32)}
# {'class': 0, 'prob': array([0.9913026 , 0.00869735], dtype=float32)}
# {'class': 1, 'prob': array([0.46483606, 0.535164  ], dtype=float32)}
# {'class': 1, 'prob': array([0.27587527, 0.72412467], dtype=float32)}
# {'class': 1, 'prob': array([0.03567323, 0.96432674], dtype=float32)}
# {'class': 0, 'prob': array([0.9913089 , 0.00869109], dtype=float32)}
# {'class': 1, 'prob': array([0.28344923, 0.71655077], dtype=float32)}
# {'class': 0, 'prob': array([0.548593  , 0.45140696], dtype=float32)}
# {'class': 0, 'prob': array([0.99848974, 0.0015102 ], dtype=float32)}
# {'class': 0, 'prob': array([0.94901615, 0.05098382], dtype=float32)}
# {'class': 0, 'prob': array([0.9965509 , 0.00344911], dtype=float32)}
# {'class': 0, 'prob': array([0.7561467 , 0.24385326], dtype=float32)}
# {'class': 0, 'prob': array([0.9987338 , 0.00126623], dtype=float32)}
# {'class': 1, 'prob': array([0.07201082, 0.9279891 ], dtype=float32)}
# {'class': 1, 'prob': array([4.4757198e-04, 9.9955243e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.9985838 , 0.00141623], dtype=float32)}
# {'class': 0, 'prob': array([0.9932749, 0.0067251], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 1, 'prob': array([0.0253399, 0.9746601], dtype=float32)}
# {'class': 0, 'prob': array([0.685897  , 0.31410298], dtype=float32)}
# {'class': 0, 'prob': array([0.9908504 , 0.00914961], dtype=float32)}
# {'class': 0, 'prob': array([0.96867573, 0.03132431], dtype=float32)}
# {'class': 1, 'prob': array([0.2623495, 0.7376506], dtype=float32)}
# {'class': 0, 'prob': array([9.9998772e-01, 1.2334821e-05], dtype=float32)}
# {'class': 0, 'prob': array([0.77449363, 0.22550638], dtype=float32)}
# {'class': 0, 'prob': array([0.99769944, 0.00230059], dtype=float32)}
# {'class': 0, 'prob': array([0.9987619 , 0.00123811], dtype=float32)}
# {'class': 0, 'prob': array([9.9953389e-01, 4.6614528e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.99307394, 0.00692605], dtype=float32)}
# {'class': 1, 'prob': array([1.113221e-05, 9.999889e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.9959484 , 0.00405164], dtype=float32)}
# {'class': 0, 'prob': array([0.9506331, 0.0493669], dtype=float32)}
# {'class': 0, 'prob': array([0.99647   , 0.00352998], dtype=float32)}
# {'class': 1, 'prob': array([0.32547545, 0.6745245 ], dtype=float32)}
# {'class': 1, 'prob': array([2.2965702e-08, 1.0000000e+00], dtype=float32)}
# {'class': 1, 'prob': array([0.02407288, 0.9759271 ], dtype=float32)}
# {'class': 1, 'prob': array([0.2739663, 0.7260337], dtype=float32)}
# {'class': 0, 'prob': array([0.9978015 , 0.00219847], dtype=float32)}
# {'class': 0, 'prob': array([0.6810111 , 0.31898895], dtype=float32)}
# {'class': 0, 'prob': array([9.9999964e-01, 3.8251198e-07], dtype=float32)}
# {'class': 1, 'prob': array([0.35157976, 0.6484203 ], dtype=float32)}
# {'class': 0, 'prob': array([0.997015  , 0.00298504], dtype=float32)}
# {'class': 0, 'prob': array([0.6978901, 0.30211  ], dtype=float32)}
# {'class': 0, 'prob': array([0.96655566, 0.03344436], dtype=float32)}
# {'class': 1, 'prob': array([1.9873222e-04, 9.9980134e-01], dtype=float32)}
# {'class': 1, 'prob': array([0.01298496, 0.987015  ], dtype=float32)}
# {'class': 0, 'prob': array([0.99044716, 0.0095529 ], dtype=float32)}
# {'class': 1, 'prob': array([0.03936514, 0.9606348 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9471655 , 0.05283449], dtype=float32)}
# {'class': 1, 'prob': array([0.35157976, 0.6484203 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9866223 , 0.01337771], dtype=float32)}
# {'class': 0, 'prob': array([9.9997365e-01, 2.6341433e-05], dtype=float32)}
# {'class': 0, 'prob': array([9.990792e-01, 9.207438e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.990537  , 0.00946305], dtype=float32)}
# {'class': 0, 'prob': array([0.81425285, 0.18574715], dtype=float32)}
# {'class': 0, 'prob': array([0.9836875 , 0.01631242], dtype=float32)}
# {'class': 1, 'prob': array([0.42095456, 0.5790454 ], dtype=float32)}
# {'class': 0, 'prob': array([0.5139056 , 0.48609442], dtype=float32)}
# {'class': 1, 'prob': array([0.12583655, 0.87416345], dtype=float32)}
# {'class': 0, 'prob': array([0.93875104, 0.06124892], dtype=float32)}
# {'class': 0, 'prob': array([0.6796775, 0.3203225], dtype=float32)}
# {'class': 0, 'prob': array([0.9906068 , 0.00939325], dtype=float32)}
# {'class': 0, 'prob': array([0.51365113, 0.48634887], dtype=float32)}
# {'class': 0, 'prob': array([0.99044716, 0.0095529 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9121869 , 0.08781301], dtype=float32)}
# {'class': 0, 'prob': array([0.99859124, 0.00140879], dtype=float32)}
# {'class': 0, 'prob': array([1.0000000e+00, 6.6532535e-10], dtype=float32)}
# {'class': 0, 'prob': array([9.9905354e-01, 9.4650878e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.5463457 , 0.45365435], dtype=float32)}
# {'class': 0, 'prob': array([0.99461395, 0.00538609], dtype=float32)}
# {'class': 1, 'prob': array([0.02292003, 0.97708   ], dtype=float32)}
# {'class': 0, 'prob': array([0.99284804, 0.00715196], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 0, 'prob': array([0.99872726, 0.00127272], dtype=float32)}
# {'class': 1, 'prob': array([0.4351527 , 0.56484735], dtype=float32)}
# {'class': 0, 'prob': array([0.99810106, 0.00189895], dtype=float32)}
# {'class': 0, 'prob': array([0.9916325, 0.0083675], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 0, 'prob': array([0.9900513 , 0.00994864], dtype=float32)}
# {'class': 0, 'prob': array([0.97449243, 0.02550763], dtype=float32)}
# {'class': 0, 'prob': array([0.96527773, 0.03472224], dtype=float32)}
# {'class': 1, 'prob': array([0.12563711, 0.8743629 ], dtype=float32)}
# {'class': 1, 'prob': array([0.02437274, 0.97562724], dtype=float32)}
# {'class': 1, 'prob': array([0.28737238, 0.71262765], dtype=float32)}
# {'class': 0, 'prob': array([0.7608934 , 0.23910663], dtype=float32)}
# {'class': 0, 'prob': array([0.9938334 , 0.00616652], dtype=float32)}
# {'class': 0, 'prob': array([0.9775359 , 0.02246408], dtype=float32)}
# {'class': 0, 'prob': array([0.54102755, 0.45897248], dtype=float32)}
# {'class': 0, 'prob': array([0.63637733, 0.36362267], dtype=float32)}
# {'class': 1, 'prob': array([0.2402816 , 0.75971836], dtype=float32)}
# {'class': 1, 'prob': array([0.04310203, 0.956898  ], dtype=float32)}
# {'class': 0, 'prob': array([0.9883571 , 0.01164282], dtype=float32)}
# {'class': 1, 'prob': array([0.0561207 , 0.94387925], dtype=float32)}
# {'class': 0, 'prob': array([0.99898154, 0.00101841], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 1, 'prob': array([0.37161636, 0.62838364], dtype=float32)}
# {'class': 0, 'prob': array([0.9972031 , 0.00279696], dtype=float32)}
# {'class': 1, 'prob': array([0.22026551, 0.7797345 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9886981 , 0.01130186], dtype=float32)}
# {'class': 0, 'prob': array([0.99753904, 0.00246097], dtype=float32)}
# {'class': 0, 'prob': array([0.9943295 , 0.00567054], dtype=float32)}
# {'class': 0, 'prob': array([0.99473417, 0.00526582], dtype=float32)}
# {'class': 1, 'prob': array([0.13954075, 0.86045927], dtype=float32)}
# {'class': 0, 'prob': array([0.99000275, 0.00999727], dtype=float32)}
# {'class': 0, 'prob': array([0.9988759 , 0.00112411], dtype=float32)}
# {'class': 0, 'prob': array([0.9975612 , 0.00243876], dtype=float32)}
# {'class': 0, 'prob': array([0.9967296 , 0.00327037], dtype=float32)}
# {'class': 0, 'prob': array([0.98829365, 0.01170638], dtype=float32)}
# {'class': 0, 'prob': array([0.586872, 0.413128], dtype=float32)}
# {'class': 0, 'prob': array([0.9957841 , 0.00421592], dtype=float32)}
# {'class': 0, 'prob': array([0.808101  , 0.19189899], dtype=float32)}
# {'class': 1, 'prob': array([1.5693769e-05, 9.9998426e-01], dtype=float32)}
# {'class': 1, 'prob': array([9.5213527e-06, 9.9999046e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.98374695, 0.01625308], dtype=float32)}
# {'class': 0, 'prob': array([0.95958537, 0.04041459], dtype=float32)}
# {'class': 0, 'prob': array([0.99894756, 0.00105249], dtype=float32)}
# {'class': 0, 'prob': array([9.9999952e-01, 4.7769373e-07], dtype=float32)}
# {'class': 0, 'prob': array([0.9971589 , 0.00284117], dtype=float32)}
# {'class': 0, 'prob': array([0.7474971 , 0.25250295], dtype=float32)}
# {'class': 0, 'prob': array([0.94751114, 0.05248889], dtype=float32)}
# {'class': 1, 'prob': array([3.7399521e-05, 9.9996257e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.97546685, 0.0245332 ], dtype=float32)}
# {'class': 0, 'prob': array([9.9999416e-01, 5.8293513e-06], dtype=float32)}
# {'class': 0, 'prob': array([0.7340196 , 0.26598033], dtype=float32)}
# {'class': 0, 'prob': array([9.9932814e-01, 6.7188492e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.99759537, 0.00240466], dtype=float32)}
# {'class': 1, 'prob': array([0.02258047, 0.9774195 ], dtype=float32)}
# {'class': 0, 'prob': array([0.5898061 , 0.41019398], dtype=float32)}
# {'class': 0, 'prob': array([0.9660248 , 0.03397518], dtype=float32)}
# {'class': 0, 'prob': array([0.59769773, 0.4023023 ], dtype=float32)}
# {'class': 1, 'prob': array([0.1259508 , 0.87404925], dtype=float32)}
# {'class': 0, 'prob': array([0.98738015, 0.0126199 ], dtype=float32)}
# {'class': 1, 'prob': array([0.15995647, 0.8400435 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9910426, 0.0089574], dtype=float32)}
# {'class': 0, 'prob': array([0.9879952 , 0.01200483], dtype=float32)}
# {'class': 0, 'prob': array([0.69086725, 0.30913278], dtype=float32)}
# {'class': 0, 'prob': array([0.9830768 , 0.01692325], dtype=float32)}
# {'class': 0, 'prob': array([0.9981178 , 0.00188222], dtype=float32)}
# {'class': 1, 'prob': array([0.00397469, 0.9960253 ], dtype=float32)}
# {'class': 0, 'prob': array([0.5586064 , 0.44139364], dtype=float32)}
# {'class': 0, 'prob': array([0.9907354 , 0.00926459], dtype=float32)}
# {'class': 0, 'prob': array([0.99689   , 0.00311003], dtype=float32)}
# {'class': 0, 'prob': array([0.9985281, 0.0014719], dtype=float32)}
# {'class': 0, 'prob': array([0.9764347 , 0.02356529], dtype=float32)}
# {'class': 0, 'prob': array([0.9979157 , 0.00208434], dtype=float32)}
# {'class': 1, 'prob': array([0.01820848, 0.9817915 ], dtype=float32)}
# {'class': 1, 'prob': array([0.02723663, 0.9727633 ], dtype=float32)}
# {'class': 0, 'prob': array([0.99333304, 0.00666701], dtype=float32)}
# {'class': 1, 'prob': array([2.4528246e-04, 9.9975473e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.73558646, 0.26441354], dtype=float32)}
# {'class': 0, 'prob': array([0.9471655 , 0.05283449], dtype=float32)}
# {'class': 0, 'prob': array([0.88789046, 0.11210952], dtype=float32)}
# {'class': 0, 'prob': array([9.9999976e-01, 2.6882634e-07], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 1, 'prob': array([0.00492108, 0.9950789 ], dtype=float32)}
# {'class': 0, 'prob': array([0.98460716, 0.01539276], dtype=float32)}
# {'class': 1, 'prob': array([0.07617276, 0.92382723], dtype=float32)}
# {'class': 0, 'prob': array([9.9920756e-01, 7.9244928e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.98799485, 0.01200514], dtype=float32)}
# {'class': 0, 'prob': array([0.9872491 , 0.01275096], dtype=float32)}
# {'class': 0, 'prob': array([0.9549741 , 0.04502595], dtype=float32)}
# {'class': 0, 'prob': array([0.7538658 , 0.24613424], dtype=float32)}
# {'class': 0, 'prob': array([0.9964588 , 0.00354114], dtype=float32)}
# {'class': 0, 'prob': array([9.9971277e-01, 2.8725748e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.82775956, 0.1722405 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9946806 , 0.00531945], dtype=float32)}
# {'class': 1, 'prob': array([0.00126394, 0.9987361 ], dtype=float32)}
# {'class': 0, 'prob': array([0.518155, 0.481845], dtype=float32)}
# {'class': 0, 'prob': array([0.97898257, 0.02101739], dtype=float32)}
# {'class': 1, 'prob': array([0.28266445, 0.7173355 ], dtype=float32)}
# {'class': 1, 'prob': array([0.08166772, 0.9183323 ], dtype=float32)}
# {'class': 0, 'prob': array([0.98739374, 0.01260621], dtype=float32)}
# {'class': 1, 'prob': array([1.0442698e-07, 9.9999988e-01], dtype=float32)}
# {'class': 1, 'prob': array([0.05298794, 0.947012  ], dtype=float32)}
# {'class': 0, 'prob': array([0.98857445, 0.01142556], dtype=float32)}
# {'class': 0, 'prob': array([0.5417415 , 0.45825854], dtype=float32)}
# {'class': 0, 'prob': array([0.52309066, 0.4769093 ], dtype=float32)}
# {'class': 0, 'prob': array([0.98078406, 0.01921586], dtype=float32)}
# {'class': 1, 'prob': array([0.00732885, 0.99267113], dtype=float32)}
# {'class': 0, 'prob': array([0.99858546, 0.00141455], dtype=float32)}
# {'class': 0, 'prob': array([0.9858169 , 0.01418307], dtype=float32)}
# {'class': 0, 'prob': array([0.99101514, 0.0089849 ], dtype=float32)}
# {'class': 0, 'prob': array([0.7961871 , 0.20381297], dtype=float32)}
# {'class': 0, 'prob': array([0.9715182 , 0.02848182], dtype=float32)}
# {'class': 0, 'prob': array([0.9909059 , 0.00909406], dtype=float32)}
# {'class': 0, 'prob': array([0.9366345 , 0.06336557], dtype=float32)}
# {'class': 1, 'prob': array([0.124956 , 0.8750439], dtype=float32)}
# {'class': 0, 'prob': array([0.8944292 , 0.10557079], dtype=float32)}
# {'class': 1, 'prob': array([0.0308914, 0.9691086], dtype=float32)}
# {'class': 0, 'prob': array([0.99044716, 0.0095529 ], dtype=float32)}
# {'class': 1, 'prob': array([0.05648378, 0.9435162 ], dtype=float32)}
# {'class': 0, 'prob': array([0.99698645, 0.00301357], dtype=float32)}
# {'class': 1, 'prob': array([9.059591e-04, 9.990940e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.99703336, 0.00296668], dtype=float32)}
# {'class': 1, 'prob': array([0.09575178, 0.90424824], dtype=float32)}
# {'class': 1, 'prob': array([0.09555313, 0.90444684], dtype=float32)}
# {'class': 0, 'prob': array([0.99736303, 0.00263692], dtype=float32)}
# {'class': 1, 'prob': array([0.12583655, 0.87416345], dtype=float32)}
# {'class': 0, 'prob': array([0.9979305 , 0.00206943], dtype=float32)}
# {'class': 0, 'prob': array([0.9885988 , 0.01140122], dtype=float32)}
# {'class': 0, 'prob': array([0.79938096, 0.200619  ], dtype=float32)}
# {'class': 1, 'prob': array([0.03478649, 0.96521354], dtype=float32)}
# {'class': 0, 'prob': array([0.9987949 , 0.00120502], dtype=float32)}
# {'class': 0, 'prob': array([0.9736884 , 0.02631155], dtype=float32)}
# {'class': 0, 'prob': array([0.9322597 , 0.06774025], dtype=float32)}
# {'class': 0, 'prob': array([0.996842  , 0.00315803], dtype=float32)}
# {'class': 0, 'prob': array([9.998005e-01, 1.994901e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.99204224, 0.00795782], dtype=float32)}
# {'class': 1, 'prob': array([0.2049711 , 0.79502887], dtype=float32)}
# {'class': 0, 'prob': array([1.000000e+00, 4.922535e-09], dtype=float32)}
# {'class': 0, 'prob': array([0.63101095, 0.36898908], dtype=float32)}
# {'class': 0, 'prob': array([0.67751974, 0.32248032], dtype=float32)}
# {'class': 0, 'prob': array([0.6065143 , 0.39348572], dtype=float32)}
# {'class': 0, 'prob': array([0.99054176, 0.00945824], dtype=float32)}
# {'class': 0, 'prob': array([0.99008477, 0.00991529], dtype=float32)}
# {'class': 0, 'prob': array([0.9498967 , 0.05010327], dtype=float32)}
# {'class': 1, 'prob': array([0.07706432, 0.9229357 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9835127 , 0.01648735], dtype=float32)}
# {'class': 1, 'prob': array([0.2402816 , 0.75971836], dtype=float32)}
# {'class': 1, 'prob': array([0.187042, 0.812958], dtype=float32)}
# {'class': 1, 'prob': array([0.04107762, 0.9589224 ], dtype=float32)}
# {'class': 0, 'prob': array([0.99682814, 0.00317185], dtype=float32)}
# {'class': 0, 'prob': array([0.53687716, 0.4631229 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9973895 , 0.00261058], dtype=float32)}
# {'class': 0, 'prob': array([0.99394   , 0.00606002], dtype=float32)}
# {'class': 0, 'prob': array([0.9907354 , 0.00926459], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 0, 'prob': array([0.9989478, 0.0010522], dtype=float32)}
# {'class': 1, 'prob': array([0.10292063, 0.89707935], dtype=float32)}
# {'class': 0, 'prob': array([0.9970372 , 0.00296288], dtype=float32)}
# {'class': 0, 'prob': array([9.9910319e-01, 8.9679705e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.99702257, 0.00297739], dtype=float32)}
# {'class': 1, 'prob': array([0.15234978, 0.84765023], dtype=float32)}
# {'class': 1, 'prob': array([0.43651626, 0.5634837 ], dtype=float32)}
# {'class': 0, 'prob': array([0.87060344, 0.12939653], dtype=float32)}
# {'class': 0, 'prob': array([0.990537  , 0.00946305], dtype=float32)}
# {'class': 0, 'prob': array([9.9995184e-01, 4.8102000e-05], dtype=float32)}
# {'class': 0, 'prob': array([0.9907354 , 0.00926459], dtype=float32)}
# {'class': 1, 'prob': array([0.28344923, 0.71655077], dtype=float32)}
# {'class': 0, 'prob': array([0.99575233, 0.00424764], dtype=float32)}
# {'class': 0, 'prob': array([0.9898808 , 0.01011922], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 1, 'prob': array([0.00174406, 0.9982559 ], dtype=float32)}
# {'class': 1, 'prob': array([0.16702153, 0.8329785 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9764407 , 0.02355931], dtype=float32)}
# {'class': 1, 'prob': array([0.11025205, 0.889748  ], dtype=float32)}
# {'class': 0, 'prob': array([0.9913045 , 0.00869552], dtype=float32)}
# {'class': 0, 'prob': array([0.9870006 , 0.01299938], dtype=float32)}
# {'class': 0, 'prob': array([0.9595766 , 0.04042343], dtype=float32)}
# {'class': 0, 'prob': array([0.97701615, 0.02298383], dtype=float32)}
# {'class': 0, 'prob': array([0.57765436, 0.42234558], dtype=float32)}
# {'class': 0, 'prob': array([0.9945146 , 0.00548542], dtype=float32)}
# {'class': 1, 'prob': array([0.12583655, 0.87416345], dtype=float32)}
# {'class': 1, 'prob': array([0.25147095, 0.7485291 ], dtype=float32)}
# {'class': 1, 'prob': array([0.3333621 , 0.66663784], dtype=float32)}
# {'class': 0, 'prob': array([0.99887854, 0.00112149], dtype=float32)}
# {'class': 0, 'prob': array([0.9909043 , 0.00909575], dtype=float32)}
# {'class': 0, 'prob': array([0.9760191 , 0.02398087], dtype=float32)}
# {'class': 0, 'prob': array([0.97191566, 0.02808434], dtype=float32)}
# {'class': 0, 'prob': array([0.99044716, 0.0095529 ], dtype=float32)}
# {'class': 0, 'prob': array([0.56902397, 0.430976  ], dtype=float32)}
# {'class': 1, 'prob': array([0.21104445, 0.78895557], dtype=float32)}
# {'class': 0, 'prob': array([0.9764347 , 0.02356529], dtype=float32)}
# {'class': 1, 'prob': array([0.01605767, 0.98394233], dtype=float32)}
# {'class': 0, 'prob': array([0.9987112, 0.0012888], dtype=float32)}
# {'class': 0, 'prob': array([0.99872094, 0.00127901], dtype=float32)}
# {'class': 1, 'prob': array([0.00690053, 0.99309945], dtype=float32)}
# {'class': 0, 'prob': array([0.988734  , 0.01126607], dtype=float32)}
# {'class': 0, 'prob': array([0.5811884 , 0.41881162], dtype=float32)}
# {'class': 0, 'prob': array([9.9905628e-01, 9.4377843e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.9944277 , 0.00557228], dtype=float32)}
# {'class': 1, 'prob': array([0.25580874, 0.7441913 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9832696 , 0.01673046], dtype=float32)}
# {'class': 0, 'prob': array([0.99746823, 0.00253174], dtype=float32)}
# {'class': 1, 'prob': array([0.12583655, 0.87416345], dtype=float32)}
# {'class': 0, 'prob': array([0.9887639 , 0.01123611], dtype=float32)}
# {'class': 0, 'prob': array([0.98376113, 0.0162389 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9905888 , 0.00941122], dtype=float32)}
# {'class': 1, 'prob': array([0.01810708, 0.98189294], dtype=float32)}
# {'class': 0, 'prob': array([0.9837219, 0.0162781], dtype=float32)}
# {'class': 0, 'prob': array([0.9962657 , 0.00373425], dtype=float32)}
# {'class': 0, 'prob': array([0.9929228 , 0.00707719], dtype=float32)}
# {'class': 0, 'prob': array([0.9907212, 0.0092788], dtype=float32)}
# {'class': 0, 'prob': array([0.5524544, 0.4475456], dtype=float32)}
# {'class': 1, 'prob': array([0.02847384, 0.9715262 ], dtype=float32)}
# {'class': 1, 'prob': array([0.25069743, 0.7493025 ], dtype=float32)}
# {'class': 1, 'prob': array([0.20415002, 0.79585   ], dtype=float32)}
# {'class': 0, 'prob': array([0.9722998 , 0.02770023], dtype=float32)}
# {'class': 0, 'prob': array([0.99884546, 0.00115448], dtype=float32)}
# {'class': 0, 'prob': array([0.98937935, 0.01062065], dtype=float32)}
# {'class': 0, 'prob': array([0.99872726, 0.00127272], dtype=float32)}
# {'class': 0, 'prob': array([0.9984274 , 0.00157263], dtype=float32)}
# {'class': 0, 'prob': array([0.7389487, 0.2610513], dtype=float32)}
# {'class': 0, 'prob': array([0.8447952 , 0.15520479], dtype=float32)}
# {'class': 1, 'prob': array([0.00339166, 0.9966084 ], dtype=float32)}
# {'class': 0, 'prob': array([0.99748176, 0.0025183 ], dtype=float32)}
# {'class': 1, 'prob': array([3.151733e-04, 9.996848e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.9948637, 0.0051363], dtype=float32)}
# {'class': 0, 'prob': array([0.99414694, 0.0058531 ], dtype=float32)}
# {'class': 0, 'prob': array([0.97186613, 0.02813384], dtype=float32)}
# {'class': 0, 'prob': array([0.6833618 , 0.31663817], dtype=float32)}
# {'class': 0, 'prob': array([0.90379775, 0.09620225], dtype=float32)}
# {'class': 0, 'prob': array([0.9764407 , 0.02355931], dtype=float32)}
# {'class': 1, 'prob': array([0.38689306, 0.61310697], dtype=float32)}
# {'class': 0, 'prob': array([0.99884355, 0.00115644], dtype=float32)}
# {'class': 1, 'prob': array([0.00790559, 0.99209446], dtype=float32)}
# {'class': 0, 'prob': array([0.9521117 , 0.04788824], dtype=float32)}
# {'class': 0, 'prob': array([0.99775213, 0.00224791], dtype=float32)}
# {'class': 0, 'prob': array([0.97277033, 0.02722964], dtype=float32)}
# {'class': 0, 'prob': array([0.9764347 , 0.02356529], dtype=float32)}
# {'class': 0, 'prob': array([0.9706633 , 0.02933669], dtype=float32)}
# {'class': 0, 'prob': array([0.99449664, 0.00550334], dtype=float32)}
# {'class': 0, 'prob': array([0.9946812 , 0.00531882], dtype=float32)}
# {'class': 1, 'prob': array([2.3661179e-10, 1.0000000e+00], dtype=float32)}
# {'class': 0, 'prob': array([0.99400604, 0.00599395], dtype=float32)}
# {'class': 1, 'prob': array([0.47301906, 0.5269809 ], dtype=float32)}
# {'class': 0, 'prob': array([0.98829365, 0.01170638], dtype=float32)}
# {'class': 0, 'prob': array([0.59787434, 0.40212566], dtype=float32)}
# {'class': 0, 'prob': array([0.9779769 , 0.02202304], dtype=float32)}
# {'class': 1, 'prob': array([0.04671365, 0.95328635], dtype=float32)}
# {'class': 1, 'prob': array([0.39653352, 0.6034665 ], dtype=float32)}
# {'class': 0, 'prob': array([0.98857445, 0.01142556], dtype=float32)}
# {'class': 0, 'prob': array([0.8873502 , 0.11264981], dtype=float32)}
# {'class': 0, 'prob': array([9.9984813e-01, 1.5190436e-04], dtype=float32)}
# {'class': 1, 'prob': array([0.31494805, 0.6850519 ], dtype=float32)}
# {'class': 0, 'prob': array([0.98415554, 0.01584451], dtype=float32)}
# {'class': 1, 'prob': array([0.01170052, 0.9882995 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9905466 , 0.00945343], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 1, 'prob': array([0.48338225, 0.5166177 ], dtype=float32)}
# {'class': 0, 'prob': array([9.999925e-01, 7.492736e-06], dtype=float32)}
# {'class': 1, 'prob': array([0.03064442, 0.9693555 ], dtype=float32)}
# {'class': 1, 'prob': array([0.04671365, 0.95328635], dtype=float32)}
# {'class': 0, 'prob': array([0.99880683, 0.00119318], dtype=float32)}
# {'class': 1, 'prob': array([8.9989398e-06, 9.9999106e-01], dtype=float32)}
# {'class': 1, 'prob': array([0.23579824, 0.7642017 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9836835 , 0.01631649], dtype=float32)}
# {'class': 1, 'prob': array([0.15902139, 0.8409786 ], dtype=float32)}
# {'class': 1, 'prob': array([0.4221817 , 0.57781833], dtype=float32)}
# {'class': 0, 'prob': array([0.9754277 , 0.02457235], dtype=float32)}
# {'class': 0, 'prob': array([0.9889015 , 0.01109857], dtype=float32)}
# {'class': 1, 'prob': array([1.6820473e-05, 9.9998319e-01], dtype=float32)}
# {'class': 0, 'prob': array([9.9989843e-01, 1.0151360e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.9899843 , 0.01001577], dtype=float32)}
# {'class': 1, 'prob': array([7.438791e-05, 9.999256e-01], dtype=float32)}
# {'class': 1, 'prob': array([0.0014431, 0.9985569], dtype=float32)}
# {'class': 0, 'prob': array([0.8697359, 0.1302641], dtype=float32)}
# {'class': 0, 'prob': array([0.9737762 , 0.02622376], dtype=float32)}
# {'class': 0, 'prob': array([0.9978818 , 0.00211816], dtype=float32)}
# {'class': 0, 'prob': array([9.9909496e-01, 9.0510934e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.97389245, 0.02610753], dtype=float32)}
# {'class': 0, 'prob': array([0.99574214, 0.00425786], dtype=float32)}
# {'class': 1, 'prob': array([0.20973983, 0.79026014], dtype=float32)}
# {'class': 0, 'prob': array([0.6080024 , 0.39199752], dtype=float32)}
# {'class': 0, 'prob': array([0.9144437 , 0.08555635], dtype=float32)}
# {'class': 1, 'prob': array([0.10928673, 0.8907132 ], dtype=float32)}
# {'class': 0, 'prob': array([0.9975701 , 0.00242984], dtype=float32)}
# {'class': 0, 'prob': array([9.99892116e-01, 1.07931344e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.9916687 , 0.00833123], dtype=float32)}
# {'class': 0, 'prob': array([0.99857557, 0.00142444], dtype=float32)}
# {'class': 0, 'prob': array([0.9213098 , 0.07869016], dtype=float32)}
# {'class': 1, 'prob': array([0.00157011, 0.99842983], dtype=float32)}
# {'class': 0, 'prob': array([0.99001676, 0.00998319], dtype=float32)}
# {'class': 0, 'prob': array([9.9961507e-01, 3.8494254e-04], dtype=float32)}
# {'class': 0, 'prob': array([9.999186e-01, 8.141600e-05], dtype=float32)}
# {'class': 1, 'prob': array([0.0940258, 0.9059742], dtype=float32)}
# {'class': 0, 'prob': array([0.993224  , 0.00677605], dtype=float32)}
# {'class': 1, 'prob': array([3.9752044e-06, 9.9999607e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.9972066 , 0.00279337], dtype=float32)}
# {'class': 0, 'prob': array([0.9841022 , 0.01589781], dtype=float32)}
# {'class': 1, 'prob': array([2.3846104e-07, 9.9999976e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.99266714, 0.00733286], dtype=float32)}
# {'class': 1, 'prob': array([0.00995221, 0.9900478 ], dtype=float32)}
# {'class': 0, 'prob': array([0.687764  , 0.31223595], dtype=float32)}
# {'class': 0, 'prob': array([0.9343613 , 0.06563863], dtype=float32)}
# {'class': 0, 'prob': array([0.90345234, 0.09654765], dtype=float32)}
# {'class': 0, 'prob': array([0.9911556 , 0.00884439], dtype=float32)}
# {'class': 0, 'prob': array([0.95038956, 0.04961045], dtype=float32)}
# {'class': 1, 'prob': array([0.12603632, 0.8739637 ], dtype=float32)}
# {'class': 1, 'prob': array([0.44136342, 0.5586366 ], dtype=float32)}
# {'class': 1, 'prob': array([0.12583655, 0.87416345], dtype=float32)}
# {'class': 1, 'prob': array([2.8891953e-05, 9.9997115e-01], dtype=float32)}
# {'class': 0, 'prob': array([0.6872876 , 0.31271234], dtype=float32)}
# {'class': 0, 'prob': array([0.99044716, 0.0095529 ], dtype=float32)}
# {'class': 1, 'prob': array([4.0609163e-04, 9.9959391e-01], dtype=float32)}
# {'class': 0, 'prob': array([9.9903238e-01, 9.6764544e-04], dtype=float32)}
# {'class': 0, 'prob': array([0.99044716, 0.0095529 ], dtype=float32)}
# {'class': 0, 'prob': array([0.974835  , 0.02516497], dtype=float32)}
